# %% [markdown]
# __Sean Tulin__
# <br>
# Date: Jan. 10, 2021
# <br>
# PHYS 2030 W22

# %% [markdown]
# # <center><font color=#46769B>Exercise 0: Hello world!</font></center>
#
# This is a test exercise. Please define $a$ and $b$ to be constants of your choice and save the code to GitHub classroom.

# %%
import numpy as np
import matplotlib.pyplot as plt

a = 3
b = 3

x = np.linspace(0,10)
y = a*x + b

plt.plot(x,y)
